# %% [markdown]
# <a href="https://colab.research.google.com/github/karthikeya0020/data-handling/blob/main/casestudyonbankingsector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.DataFrame({
    'Age Group': ['18-25', '26-35', '36-45', '46-55', '55+'] * 4,
    'Total Loans': [100, 200, 300, 400, 500] * 4,
    'Number of Bad Loans': [5, 10, 15, 20, 25] * 4,
    'Number of Good Loans': [95, 190, 285, 380, 475] * 4
})
df['Percentage of Bad Loans'] = df['Number of Bad Loans'] / df['Total Loans'] * 100
df['Percentage of Good Loans'] = df['Number of Good Loans'] / df['Total Loans'] * 100

print(df)
# Out:
#    Age Group  Total Loans  Number of Bad Loans  Number of Good Loans  \
# 0      18-25          100                    5                    95
# 1      26-35          200                   10                   190
# 2      36-45          300                   15                   285
# 3      46-55          400                   20                   380
# 4        55+          500                   25                   475
# 5      18-25          100                    5                    95
# 6      26-35          200                   10                   190
# 7      36-45          300                   15                   285
# 8      46-55          400                   20                   380
# 9        55+          500                   25                   475
# 10     18-25          100                    5                    95
# 11     26-35          200                   10                   190
# 12     36-45          300                   15                   285
# 13     46-55          400                   20                   380
# 14       55+          500                   25                   475
# 15     18-25          100                    5                    95
# 16     26-35          200                   10                   190
# 17     36-45          300                   15                   285
# 18     46-55          400                   20                   380
# 19       55+          500                   25                   475
#
#     Percentage of Bad Loans  Percentage of Good Loans
# 0                       5.0                      95.0
# 1                       5.0                      95.0
# 2                       5.0                      95.0
# 3                       5.0                      95.0
# 4                       5.0                      95.0
# 5                       5.0                      95.0
# 6                       5.0                      95.0
# 7                       5.0                      95.0
# 8                       5.0                      95.0
# 9                       5.0                      95.0
# 10                      5.0                      95.0
# 11                      5.0                      95.0
# 12                      5.0                      95.0
# 13                      5.0                      95.0
# 14                      5.0                      95.0
# 15                      5.0                      95.0
# 16                      5.0                      95.0
# 17                      5.0                      95.0
# 18                      5.0                      95.0
# 19                      5.0                      95.0

# %%
import matplotlib.pyplot as plt

max_loan_age_group = df.loc[df['Total Loans'].idxmax(), 'Age Group']

plt.figure(figsize=(8, 6))
plt.bar(df['Age Group'], df['Total Loans'], color='skyblue')
plt.title('Total Loans by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Total Loans')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

plt.bar(max_loan_age_group, df.loc[df['Age Group'] == max_loan_age_group, 'Total Loans'], color='red')

plt.show()
